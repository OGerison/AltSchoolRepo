# %% [markdown]
# ### Let's talk about Pandas
# We chose Pandas well because you can do alot with it and accomplish using it from Data Cleaning to Exploratory Data Analysis to even basic Data Visualization.
#
# We have implemented pandas functions to our dataset gotten from Kaggle https://www.kaggle.com/datasets/rishikeshkonapure/hr-analytics-prediction/ to help us show you the power of pandas.

# %%
# Importing the pandas library we need
import pandas as pd

# %%
# Reading the dataset into a dataframe
file_path = "E:\AltSchoolofData\Semester 1\Projects\HR-Employee-Attrition.csv"
df = pd.read_csv(file_path)

# %%
# Finding the number of rows and columns in our dataframe
df.shape
# Out:
# (1470, 35)

# %%
# We can use head to see the first 5 rows of out dataframe
df.head()
# Out:
#    Age Attrition     BusinessTravel  DailyRate              Department  \
# 0   41       Yes      Travel_Rarely       1102                   Sales
# 1   49        No  Travel_Frequently        279  Research & Development
# 2   37       Yes      Travel_Rarely       1373  Research & Development
# 3   33        No  Travel_Frequently       1392  Research & Development
# 4   27        No      Travel_Rarely        591  Research & Development
#
#    DistanceFromHome  Education EducationField  EmployeeCount  EmployeeNumber  \
# 0                 1          2  Life Sciences              1               1
# 1                 8          1  Life Sciences              1               2
# 2                 2          2          Other              1               4
# 3                 3          4  Life Sciences              1               5
# 4                 2          1        Medical              1               7
#
#    ...  RelationshipSatisfaction StandardHours  StockOptionLevel  \
# ...

# %%
# Or tail to see the last 5 rows.
df.tail()
# Out:
#       Age Attrition     BusinessTravel  DailyRate              Department  \
# 1465   36        No  Travel_Frequently        884  Research & Development
# 1466   39        No      Travel_Rarely        613  Research & Development
# 1467   27        No      Travel_Rarely        155  Research & Development
# 1468   49        No  Travel_Frequently       1023                   Sales
# 1469   34        No      Travel_Rarely        628  Research & Development
#
#       DistanceFromHome  Education EducationField  EmployeeCount  \
# 1465                23          2        Medical              1
# 1466                 6          1        Medical              1
# 1467                 4          3  Life Sciences              1
# 1468                 2          3        Medical              1
# 1469                 8          3        Medical              1
#
#       EmployeeNumber  ...  RelationshipSatisfaction StandardHours  \
# ...

# %%
# Finding out the columns we have in our dataframe
df.columns
# Out:
# Index(['Age', 'Attrition', 'BusinessTravel', 'DailyRate', 'Department',
#        'DistanceFromHome', 'Education', 'EducationField', 'EmployeeCount',
#        'EmployeeNumber', 'EnvironmentSatisfaction', 'Gender', 'HourlyRate',
#        'JobInvolvement', 'JobLevel', 'JobRole', 'JobSatisfaction',
#        'MaritalStatus', 'MonthlyIncome', 'MonthlyRate', 'NumCompaniesWorked',
#        'Over18', 'OverTime', 'PercentSalaryHike', 'PerformanceRating',
#        'RelationshipSatisfaction', 'StandardHours', 'StockOptionLevel',
#        'TotalWorkingYears', 'TrainingTimesLastYear', 'WorkLifeBalance',
#        'YearsAtCompany', 'YearsInCurrentRole', 'YearsSinceLastPromotion',
#        'YearsWithCurrManager'],
#       dtype='object')

# %%
# Describing the data to understand and see how it is distributed.
df.describe()
# Out:
#                Age    DailyRate  DistanceFromHome    Education  EmployeeCount  \
# count  1470.000000  1470.000000       1470.000000  1470.000000         1470.0
# mean     36.923810   802.485714          9.192517     2.912925            1.0
# std       9.135373   403.509100          8.106864     1.024165            0.0
# min      18.000000   102.000000          1.000000     1.000000            1.0
# 25%      30.000000   465.000000          2.000000     2.000000            1.0
# 50%      36.000000   802.000000          7.000000     3.000000            1.0
# 75%      43.000000  1157.000000         14.000000     4.000000            1.0
# max      60.000000  1499.000000         29.000000     5.000000            1.0
#
#        EmployeeNumber  EnvironmentSatisfaction   HourlyRate  JobInvolvement  \
# count     1470.000000              1470.000000  1470.000000     1470.000000
# mean      1024.865306                 2.721769    65.891156        2.729932
# ...

# %%
# Checking the data types.
df.dtypes
# Out:
# Age                          int64
# Attrition                   object
# BusinessTravel              object
# DailyRate                    int64
# Department                  object
# DistanceFromHome             int64
# Education                    int64
# EducationField              object
# EmployeeCount                int64
# EmployeeNumber               int64
# EnvironmentSatisfaction      int64
# Gender                      object
# HourlyRate                   int64
# JobInvolvement               int64
# JobLevel                     int64
# JobRole                     object
# JobSatisfaction              int64
# MaritalStatus               object
# MonthlyIncome                int64
# MonthlyRate                  int64
# NumCompaniesWorked           int64
# Over18                      object
# OverTime                    object
# PercentSalaryHike            int64
# PerformanceRating            int64
# RelationshipSatisfaction     int64
# StandardHours                int64
# ...

# %%
# Checking for the number of null values in each column
df.isna().sum()
# Out:
# Age                         0
# Attrition                   0
# BusinessTravel              0
# DailyRate                   0
# Department                  0
# DistanceFromHome            0
# Education                   0
# EducationField              0
# EmployeeCount               0
# EmployeeNumber              0
# EnvironmentSatisfaction     0
# Gender                      0
# HourlyRate                  0
# JobInvolvement              0
# JobLevel                    0
# JobRole                     0
# JobSatisfaction             0
# MaritalStatus               0
# MonthlyIncome               0
# MonthlyRate                 0
# NumCompaniesWorked          0
# Over18                      0
# OverTime                    0
# PercentSalaryHike           0
# PerformanceRating           0
# RelationshipSatisfaction    0
# StandardHours               0
# StockOptionLevel            0
# TotalWorkingYears           0
# TrainingTimesLastYear       0
# WorkLifeBalance             0
# ...

# %% [markdown]
# Our dataframe did not have null values so we did not use df.dropna() to drop such values or df.fillna() to fill the missing values.

# %%
# We decided to drop certain columns from our dataframe
df.drop(["StockOptionLevel", "JobInvolvement"], inplace=True, axis=1)

# %%
#Rename the age column since its current name did not make sense.
df.rename(columns={"ï»¿Age": "Age"}, inplace=True)

# %%
# Using Valuecounts to find out how much the employees travelled.
df["BusinessTravel"].value_counts()
# Out:
# Travel_Rarely        1043
# Travel_Frequently     277
# Non-Travel            150
# Name: BusinessTravel, dtype: int64

# %%
# But when we add normalize, it gives the value_counts a max value of 1 so they are like in the same range
df["BusinessTravel"].value_counts(normalize=True)
# Out:
# Travel_Rarely        0.709524
# Travel_Frequently    0.188435
# Non-Travel           0.102041
# Name: BusinessTravel, dtype: float64

# %%
# Finding out the mean of a column
df["Age"].mean()
# Out:
# 36.923809523809524

# %%
# Finding the unique values in a column like a set picks unique values only
df.Age.unique()
# Out:
# array([41, 49, 37, 33, 27, 32, 59, 30, 38, 36, 35, 29, 31, 34, 28, 22, 53,
#        24, 21, 42, 44, 46, 39, 43, 50, 26, 48, 55, 45, 56, 23, 51, 40, 54,
#        58, 20, 25, 19, 57, 52, 47, 18, 60], dtype=int64)

# %%
# Using groupby to find average daily rate by department
df.groupby(by="Department")["DailyRate"].mean()
# Out:
# Department
# Human Resources           751.539683
# Research & Development    806.851197
# Sales                     800.275785
# Name: DailyRate, dtype: float64

# %%
# Using a pivot table to find out the average distance from home as per their educational fields.
df.pivot_table(values="DistanceFromHome", index = "EducationField", aggfunc="mean")
# Out:
#                   DistanceFromHome
# EducationField
# Human Resources           9.037037
# Life Sciences             8.955446
# Marketing                10.106918
# Medical                   9.353448
# Other                     8.926829
# Technical Degree          8.810606

# %%
# Instead of using df.head to print the first 5, lets use iloc to print the first 20 rows
df.iloc[:21]
# Out:
#     Age Attrition     BusinessTravel  DailyRate              Department  \
# 0    41       Yes      Travel_Rarely       1102                   Sales
# 1    49        No  Travel_Frequently        279  Research & Development
# 2    37       Yes      Travel_Rarely       1373  Research & Development
# 3    33        No  Travel_Frequently       1392  Research & Development
# 4    27        No      Travel_Rarely        591  Research & Development
# 5    32        No  Travel_Frequently       1005  Research & Development
# 6    59        No      Travel_Rarely       1324  Research & Development
# 7    30        No      Travel_Rarely       1358  Research & Development
# 8    38        No  Travel_Frequently        216  Research & Development
# 9    36        No      Travel_Rarely       1299  Research & Development
# 10   35        No      Travel_Rarely        809  Research & Development
# 11   29        No      Travel_Rarely        153  Research & Development
# ...

# %%
# But we can also use loc to print the first 20 rows for a column(s) we want to see based on a condition.
df.loc[df["Age"] < 30][["Age","DailyRate"]]
# Out:
#       Age  DailyRate
# 4      27        591
# 11     29        153
# 14     28        103
# 15     29       1389
# 17     22       1123
# ...   ...        ...
# 1442   29       1092
# 1459   29       1378
# 1460   29        468
# 1464   26       1167
# 1467   27        155
#
# [326 rows x 2 columns]

# %%
# We can use groupby in conjuction with get group to separate people in the sales department in a df of their own.
df.groupby(by="Department").get_group("Sales")
# Out:
#       Age Attrition     BusinessTravel  DailyRate Department  \
# 0      41       Yes      Travel_Rarely       1102      Sales
# 18     53        No      Travel_Rarely       1219      Sales
# 21     36       Yes      Travel_Rarely       1218      Sales
# 27     42        No      Travel_Rarely        691      Sales
# 29     46        No      Travel_Rarely        705      Sales
# ...   ...       ...                ...        ...        ...
# 1454   45        No      Travel_Rarely        374      Sales
# 1461   50       Yes      Travel_Rarely        410      Sales
# 1462   39        No      Travel_Rarely        722      Sales
# 1464   26        No      Travel_Rarely       1167      Sales
# 1468   49        No  Travel_Frequently       1023      Sales
#
#       DistanceFromHome  Education EducationField  EmployeeCount  \
# 0                    1          2  Life Sciences              1
# 18                   2          4  Life Sciences              1
# ...

# %%
# We can also do some visualizing in this case the distribution of the number of people in the diffrent departments
df["Department"].value_counts().plot(kind="barh", title="Distribution by Department", ylabel="Department",xlabel="Count")
# Out:
# <Axes: title={'center': 'Distribution by Department'}, xlabel='Count', ylabel='Department'>

# %% [markdown]
# We hope you have learnt a new function or two by going through our work and you have seen how powerful pandas is. Circle 106!!!
